# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/w2_project_data_cleaning _and_wrangling/src/')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np 
import limpieza_texto as lt
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
# uploaded = files.upload()

# %%
# 1. The white shark is the terrible bad guy.
# Variables: 'Species' and 'Fatal (Y/N)'

# %%
data1 = pd.read_csv("drive/MyDrive/Colab Notebooks/csv_data/attacks_hypothesis1.csv",encoding = "ISO-8859-1")

# %%
data1.head()
# Out:
#   Fatal (Y/N)  Shark species
# 0           N          White
# 1           N  Other Species
# 2           N          Tiger
# 3           Y          Tiger
# 4           N          Lemon

# %%
plt.figure(figsize=(25, 5))
plt.xticks(rotation=45)
to_show = data1
g = sns.histplot(x=to_show['Shark species'], hue=to_show['Fatal (Y/N)'], element="bars", shrink=.8)

# %%
g.figure.savefig("/content/drive/MyDrive/Colab Notebooks/w2_project_data_cleaning _and_wrangling/output/h1.svg")

# %% [markdown]
# # New Section

# %%
# 2. During the nighttime, sharks tend to be more fatal.
# Variables: 'Time' and 'Fatal (Y/N)'

# %%
data2 = pd.read_csv("drive/MyDrive/Colab Notebooks/csv_data/attacks_hypothesis2.csv",encoding = "ISO-8859-1")

# %%
data2.head()
# Out:
#   Fatal (Y/N) Day period
# 0           N  Afternoon
# 1           N  Afternoon
# 2           N    Morning
# 3           Y  Afternoon
# 4           N  Afternoon

# %%
plt.figure(figsize=(5, 5))
g = sns.countplot(x=data2['Day period'], hue=data2['Fatal (Y/N)'], palette="Set2")

# %%
g.figure.savefig("/content/drive/MyDrive/Colab Notebooks/w2_project_data_cleaning _and_wrangling/output/h2.svg")

# %%
# 3. Most shark attacks happen in US
# Variables: 'Country'

# %%
data3 = pd.read_csv("drive/MyDrive/Colab Notebooks/csv_data/attacks_hypothesis3.csv",encoding = "ISO-8859-1")

# %%
data3.head()
# Out:
#             Country  Attacks
# 0               USA     2229
# 1         AUSTRALIA     1338
# 2      SOUTH AFRICA      579
# 3  PAPUA NEW GUINEA      134
# 4       NEW ZEALAND      128

# %%
to_show = data3.head(30)
to_show.set_index('Country')
g = to_show.sort_values(by='Attacks').plot(x='Country', kind='barh', color='blue', figsize=(15,10))
# data3.plot(figsize=(15,10))

# %%
# fig = ax.get_figure()
g.figure.savefig("/content/drive/MyDrive/Colab Notebooks/w2_project_data_cleaning _and_wrangling/output/h3.svg")
